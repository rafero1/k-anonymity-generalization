# %% [markdown]
# # Gráficos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
try:
    import plotnine as p9
except:
    # !pip install plotnine
    import plotnine as p9

df = pd.read_csv('Dataset_Covid_CE_Anon_Gen_k1.csv')
df['anonLevel'] = 0
df2 = pd.read_csv('Dataset_Covid_CE_Anon_Gen_k2.csv')
df4 = pd.read_csv('Dataset_Covid_CE_Anon_Gen_k4.csv')
df8 = pd.read_csv('Dataset_Covid_CE_Anon_Gen_k8.csv')
df16 = pd.read_csv('Dataset_Covid_CE_Anon_Gen_k16.csv')
dfs = [df, df2, df4, df8, df16]

df_municipios = pd.read_csv('ce-regions-format.csv')

semi_id = [
    "municipioCaso",
    "sexoCaso",
    "dataNascimento",
    "resultadoFinalExame",
    "racaCor",
]

# %%
pdf = pd.DataFrame({
    'k': ['k=01', 'k=02', 'k=04', 'k=08', 'k=16'], 
    'anon_lvl_mean': [df.anonLevel.mean() for df in dfs],
    'max_anon_lvl': [df.anonLevel.max() for df in dfs]
})

pdf

(p9.ggplot(pdf)
     + p9.geom_col(p9.aes(x='k', y='anon_lvl_mean', fill='k'))
     + p9.labs(y='média', x='k', title='Média da quantidade de generalizações p/ valor de K')
     + p9.lims(y=(0, 10)))
# Out:
# <ggplot: (133879177213)>

# %%
p9.ggplot(df4) + p9.geom_bar(p9.aes(x='anonLevel')) + p9.scale_y_log10()
# Out:
# <ggplot: (133893896177)>
